# %% [markdown]
# # **Week 2 Project: Movie Ratings Analysis**

# %% [markdown]
# ## **Data Cleaning and Preprocessing**

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading dataset
movie=pd.read_csv("/content/movie_reviews.csv")
movie
# Out:
#       Rank                         Release Group   $Worldwide    $Domestic  \
# 0        1                Mission: Impossible II  546388108.0  215409889.0
# 1        2                             Gladiator  460583960.0  187705427.0
# 2        3                             Cast Away  429632142.0  233632142.0
# 3        4                       What Women Want  374111707.0  182811707.0
# 4        5                              Dinosaur  349822765.0  137748063.0
# ...    ...                                   ...          ...          ...
# 4995   196                         Devara Part 1    7361414.0    5600000.0
# 4996   197                     Kolpaçino 4 4'lük    7343114.0          0.0
# 4997   198  Lim Young Woong: Im Hero the Stadium    7305588.0          0.0
# 4998   199                                  Yolo    7241561.0    2001584.0
# 4999   200                                 Sight    7206741.0    7206741.0
#
#       Domestic %     $Foreign  Foreign %  Year                        Genres  \
# 0           39.4  330978219.0       60.6  2000   Adventure, Action, Thriller
# 1           40.8  272878533.0       59.2  2000      Action, Drama, Adventure
# 2           54.4  196000000.0       45.6  2000              Adventure, Drama
# 3           48.9  191300000.0       51.1  2000               Comedy, Romance
# 4           39.4  212074702.0       60.6  2000  Animation, Family, Adventure
# ...          ...          ...        ...   ...                           ...
# 4995        76.1    1761414.0       23.9  2024                 Action, Drama
# 4996         0.0    7343114.0      100.0  2024                        Comedy
# 4997         0.0    7305588.0      100.0  2024            Music, Documentary
# 4998        27.6    5239977.0       72.4  2024         Drama, Comedy, Action
# 4999       100.0          0.0        0.0  2024                Drama, History
#
#         Rating  Vote_Count Original_Language  \
# 0     6.126/10      6741.0                en
# 1     8.217/10     19032.0                en
# 2     7.663/10     11403.0                en
# 3      6.45/10      3944.0                en
# 4     6.544/10      2530.0                en
# ...        ...         ...               ...
# 4995    7.0/10        30.0                te
# 4996    4.0/10         4.0                tr
# 4997    0.0/10         0.0                ko
# 4998    6.3/10        70.0                zh
# 4999    6.0/10        23.0                en
#
#                           Production_Countries
# 0                     United States of America
# 1     United Kingdom, United States of America
# 2                     United States of America
# 3     United Kingdom, United States of America
# 4                     United States of America
# ...                                        ...
# 4995                                     India
# 4996                                    Turkey
# 4997                               South Korea
# 4998                                     China
# 4999                  United States of America
#
# [5000 rows x 13 columns]

# %%
# removing any duplicate values
movie=movie.drop_duplicates()
movie
# Out:
#       Rank                         Release Group   $Worldwide    $Domestic  \
# 0        1                Mission: Impossible II  546388108.0  215409889.0
# 1        2                             Gladiator  460583960.0  187705427.0
# 2        3                             Cast Away  429632142.0  233632142.0
# 3        4                       What Women Want  374111707.0  182811707.0
# 4        5                              Dinosaur  349822765.0  137748063.0
# ...    ...                                   ...          ...          ...
# 4995   196                         Devara Part 1    7361414.0    5600000.0
# 4996   197                     Kolpaçino 4 4'lük    7343114.0          0.0
# 4997   198  Lim Young Woong: Im Hero the Stadium    7305588.0          0.0
# 4998   199                                  Yolo    7241561.0    2001584.0
# 4999   200                                 Sight    7206741.0    7206741.0
#
#       Domestic %     $Foreign  Foreign %  Year                        Genres  \
# 0           39.4  330978219.0       60.6  2000   Adventure, Action, Thriller
# 1           40.8  272878533.0       59.2  2000      Action, Drama, Adventure
# 2           54.4  196000000.0       45.6  2000              Adventure, Drama
# 3           48.9  191300000.0       51.1  2000               Comedy, Romance
# 4           39.4  212074702.0       60.6  2000  Animation, Family, Adventure
# ...          ...          ...        ...   ...                           ...
# 4995        76.1    1761414.0       23.9  2024                 Action, Drama
# 4996         0.0    7343114.0      100.0  2024                        Comedy
# 4997         0.0    7305588.0      100.0  2024            Music, Documentary
# 4998        27.6    5239977.0       72.4  2024         Drama, Comedy, Action
# 4999       100.0          0.0        0.0  2024                Drama, History
#
#         Rating  Vote_Count Original_Language  \
# 0     6.126/10      6741.0                en
# 1     8.217/10     19032.0                en
# 2     7.663/10     11403.0                en
# 3      6.45/10      3944.0                en
# 4     6.544/10      2530.0                en
# ...        ...         ...               ...
# 4995    7.0/10        30.0                te
# 4996    4.0/10         4.0                tr
# 4997    0.0/10         0.0                ko
# 4998    6.3/10        70.0                zh
# 4999    6.0/10        23.0                en
#
#                           Production_Countries
# 0                     United States of America
# 1     United Kingdom, United States of America
# 2                     United States of America
# 3     United Kingdom, United States of America
# 4                     United States of America
# ...                                        ...
# 4995                                     India
# 4996                                    Turkey
# 4997                               South Korea
# 4998                                     China
# 4999                  United States of America
#
# [5000 rows x 13 columns]

# %%
# droping any unneceassry column
movie=movie.drop(columns="Original_Language")
movie
# Out:
#       Rank                         Release Group   $Worldwide    $Domestic  \
# 0        1                Mission: Impossible II  546388108.0  215409889.0
# 1        2                             Gladiator  460583960.0  187705427.0
# 2        3                             Cast Away  429632142.0  233632142.0
# 3        4                       What Women Want  374111707.0  182811707.0
# 4        5                              Dinosaur  349822765.0  137748063.0
# ...    ...                                   ...          ...          ...
# 4995   196                         Devara Part 1    7361414.0    5600000.0
# 4996   197                     Kolpaçino 4 4'lük    7343114.0          0.0
# 4997   198  Lim Young Woong: Im Hero the Stadium    7305588.0          0.0
# 4998   199                                  Yolo    7241561.0    2001584.0
# 4999   200                                 Sight    7206741.0    7206741.0
#
#       Domestic %     $Foreign  Foreign %  Year                        Genres  \
# 0           39.4  330978219.0       60.6  2000   Adventure, Action, Thriller
# 1           40.8  272878533.0       59.2  2000      Action, Drama, Adventure
# 2           54.4  196000000.0       45.6  2000              Adventure, Drama
# 3           48.9  191300000.0       51.1  2000               Comedy, Romance
# 4           39.4  212074702.0       60.6  2000  Animation, Family, Adventure
# ...          ...          ...        ...   ...                           ...
# 4995        76.1    1761414.0       23.9  2024                 Action, Drama
# 4996         0.0    7343114.0      100.0  2024                        Comedy
# 4997         0.0    7305588.0      100.0  2024            Music, Documentary
# 4998        27.6    5239977.0       72.4  2024         Drama, Comedy, Action
# 4999       100.0          0.0        0.0  2024                Drama, History
#
#         Rating  Vote_Count                      Production_Countries
# 0     6.126/10      6741.0                  United States of America
# 1     8.217/10     19032.0  United Kingdom, United States of America
# 2     7.663/10     11403.0                  United States of America
# 3      6.45/10      3944.0  United Kingdom, United States of America
# 4     6.544/10      2530.0                  United States of America
# ...        ...         ...                                       ...
# 4995    7.0/10        30.0                                     India
# 4996    4.0/10         4.0                                    Turkey
# 4997    0.0/10         0.0                               South Korea
# 4998    6.3/10        70.0                                     China
# 4999    6.0/10        23.0                  United States of America
#
# [5000 rows x 12 columns]

# %%
# checking for null values
movie.isnull().sum()
# Out:
# Rank                      0
# Release Group             0
# $Worldwide                0
# $Domestic                 0
# Domestic %                0
# $Foreign                  0
# Foreign %                 0
# Year                      0
# Genres                  178
# Rating                  170
# Vote_Count              170
# Production_Countries    200
# dtype: int64

# %%
# cleaning data
movie["Rating"]=movie["Rating"].str.replace("/10","",regex=False)
movie["Rating"]=movie["Rating"].astype(float)

# %%
# checking for 0.0 values in the columns
# Domestic %
mask = movie["Domestic %"].apply(lambda x: float(x) == 0.0)
print("Total '0.0' values in Domestic %:", mask.sum().sum())
# $Worldwide
mask = movie["$Worldwide"].apply(lambda x: float(x) == 0.0)
print("Total '0.0' values in $Worldwide:", mask.sum().sum())
# $Domestic
mask = movie["$Domestic"].apply(lambda x: float(x) == 0.0)
print("Total '0.0' values in $Domestic:", mask.sum().sum())
# $Foreign
mask = movie["$Foreign"].apply(lambda x: float(x) == 0.0)
print("Total '0.0' values in $Foreign:", mask.sum().sum())
# Foreign %
mask = movie["Foreign %"].apply(lambda x: float(x) == 0.0)
print("Total '0.0' values in Foreign %:", mask.sum().sum())
# Rating
mask = movie["Rating"].apply(lambda x: float(x) == 0.0)
print("Total '0.0' values in Rating:", mask.sum().sum())
# Vote_Count
mask = movie["Vote_Count"].apply(lambda x: float(x) == 0.0)
print("Total '0.0' values in Vote_Count:", mask.sum().sum())
# Out:
# Total '0.0' values in Domestic %: 1226
# Total '0.0' values in $Worldwide: 0
# Total '0.0' values in $Domestic: 1178
# Total '0.0' values in $Foreign: 43
# Total '0.0' values in Foreign %: 52
# Total '0.0' values in Rating: 23
# Total '0.0' values in Vote_Count: 25

# %%
# replacing the 0 values with NaN
movie["Domestic %"] = movie["Domestic %"].replace(0.0, np.nan)
movie["$Domestic"] = movie["$Domestic"].replace(0.0, np.nan)
movie["$Foreign"] = movie["$Foreign"].replace(0.0, np.nan)
movie["Foreign %"] = movie["Domestic %"].replace(0.0, np.nan)
movie["Rating"] = movie["Rating"].replace(0.0, np.nan)
movie["Vote_Count"] = movie["Vote_Count"].replace(0.0, np.nan)

# %%
# replacing the null values with median values
movie["$Domestic"]=movie["$Domestic"].fillna(movie["$Domestic"].median())
movie["Domestic %"]=movie["Domestic %"].fillna(movie["Domestic %"].median())
movie["$Foreign"]=movie["$Foreign"].fillna(movie["$Foreign"].median())
movie["Foreign %"]=movie["Foreign %"].fillna(movie["Foreign %"].median())
movie["Rating"]=movie["Rating"].fillna(movie["Rating"].median())
movie["Vote_Count"]=movie["Vote_Count"].fillna(movie["$Domestic"].median())

# %%
# checking for n/a values in case we missed it
mask = movie.applymap(lambda x: str(x).lower() == "n/a")
print("Total 'n/a' values:", mask.sum().sum())
# Out:
# Total 'n/a' values: 0
# /tmp/ipython-input-785233092.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   mask = movie.applymap(lambda x: str(x).lower() == "n/a")

# %%
# replacing the missing genre with most frequent values
movie["Genres"]=movie["Genres"].fillna(movie["Genres"].mode()[0])

# %%
# replacing the missing Production_Countries with most frequent values
movie["Production_Countries"]=movie["Production_Countries"].fillna(movie["Production_Countries"].mode()[0])

# %%
movie
# Out:
#       Rank                         Release Group   $Worldwide    $Domestic  \
# 0        1                Mission: Impossible II  546388108.0  215409889.0
# 1        2                             Gladiator  460583960.0  187705427.0
# 2        3                             Cast Away  429632142.0  233632142.0
# 3        4                       What Women Want  374111707.0  182811707.0
# 4        5                              Dinosaur  349822765.0  137748063.0
# ...    ...                                   ...          ...          ...
# 4995   196                         Devara Part 1    7361414.0    5600000.0
# 4996   197                     Kolpaçino 4 4'lük    7343114.0   32087990.5
# 4997   198  Lim Young Woong: Im Hero the Stadium    7305588.0   32087990.5
# 4998   199                                  Yolo    7241561.0    2001584.0
# 4999   200                                 Sight    7206741.0    7206741.0
#
#       Domestic %     $Foreign  Foreign %  Year                        Genres  \
# 0           39.4  330978219.0       39.4  2000   Adventure, Action, Thriller
# 1           40.8  272878533.0       40.8  2000      Action, Drama, Adventure
# 2           54.4  196000000.0       54.4  2000              Adventure, Drama
# 3           48.9  191300000.0       48.9  2000               Comedy, Romance
# 4           39.4  212074702.0       39.4  2000  Animation, Family, Adventure
# ...          ...          ...        ...   ...                           ...
# 4995        76.1    1761414.0       76.1  2024                 Action, Drama
# 4996        47.3    7343114.0       47.3  2024                        Comedy
# 4997        47.3    7305588.0       47.3  2024            Music, Documentary
# 4998        27.6    5239977.0       27.6  2024         Drama, Comedy, Action
# 4999       100.0   30487968.0      100.0  2024                Drama, History
#
#       Rating  Vote_Count                      Production_Countries
# 0      6.126      6741.0                  United States of America
# 1      8.217     19032.0  United Kingdom, United States of America
# 2      7.663     11403.0                  United States of America
# 3      6.450      3944.0  United Kingdom, United States of America
# 4      6.544      2530.0                  United States of America
# ...      ...         ...                                       ...
# 4995   7.000        30.0                                     India
# 4996   4.000         4.0                                    Turkey
# 4997   6.600  32087990.5                               South Korea
# 4998   6.300        70.0                                     China
# 4999   6.000        23.0                  United States of America
#
# [5000 rows x 12 columns]

# %%
movie.isnull().sum()
# Out:
# Rank                    0
# Release Group           0
# $Worldwide              0
# $Domestic               0
# Domestic %              0
# $Foreign                0
# Foreign %               0
# Year                    0
# Genres                  0
# Rating                  0
# Vote_Count              0
# Production_Countries    0
# dtype: int64

# %%
# adding a new column based on the rating
def grade_from_rating(r):
    if r >= 8:
        return 'A'
    elif r >= 6:
        return 'B'
    elif r >= 4:
        return 'C'
    else:
        return 'D'

movie["Grade"] = movie["Rating"].apply(grade_from_rating)

# %%
movie
# Out:
#       Rank                         Release Group   $Worldwide    $Domestic  \
# 0        1                Mission: Impossible II  546388108.0  215409889.0
# 1        2                             Gladiator  460583960.0  187705427.0
# 2        3                             Cast Away  429632142.0  233632142.0
# 3        4                       What Women Want  374111707.0  182811707.0
# 4        5                              Dinosaur  349822765.0  137748063.0
# ...    ...                                   ...          ...          ...
# 4995   196                         Devara Part 1    7361414.0    5600000.0
# 4996   197                     Kolpaçino 4 4'lük    7343114.0   32087990.5
# 4997   198  Lim Young Woong: Im Hero the Stadium    7305588.0   32087990.5
# 4998   199                                  Yolo    7241561.0    2001584.0
# 4999   200                                 Sight    7206741.0    7206741.0
#
#       Domestic %     $Foreign  Foreign %  Year                        Genres  \
# 0           39.4  330978219.0       39.4  2000   Adventure, Action, Thriller
# 1           40.8  272878533.0       40.8  2000      Action, Drama, Adventure
# 2           54.4  196000000.0       54.4  2000              Adventure, Drama
# 3           48.9  191300000.0       48.9  2000               Comedy, Romance
# 4           39.4  212074702.0       39.4  2000  Animation, Family, Adventure
# ...          ...          ...        ...   ...                           ...
# 4995        76.1    1761414.0       76.1  2024                 Action, Drama
# 4996        47.3    7343114.0       47.3  2024                        Comedy
# 4997        47.3    7305588.0       47.3  2024            Music, Documentary
# 4998        27.6    5239977.0       27.6  2024         Drama, Comedy, Action
# 4999       100.0   30487968.0      100.0  2024                Drama, History
#
#       Rating  Vote_Count                      Production_Countries Grade
# 0      6.126      6741.0                  United States of America     B
# 1      8.217     19032.0  United Kingdom, United States of America     A
# 2      7.663     11403.0                  United States of America     B
# 3      6.450      3944.0  United Kingdom, United States of America     B
# 4      6.544      2530.0                  United States of America     B
# ...      ...         ...                                       ...   ...
# 4995   7.000        30.0                                     India     B
# 4996   4.000         4.0                                    Turkey     C
# 4997   6.600  32087990.5                               South Korea     B
# 4998   6.300        70.0                                     China     B
# 4999   6.000        23.0                  United States of America     B
#
# [5000 rows x 13 columns]

# %% [markdown]
# ## **Data Visualization**

# %% [markdown]
# ### **Scatter Plot**

# %%
# plotting scatter plot based on domestic vs worldwide gross sale
sns.scatterplot(data=movie, x="$Domestic", y="$Worldwide", hue="Grade")
plt.title("Domestic Budget vs Worldwide Gross by Grade")
plt.xlabel("Domestic Budget ($)")
plt.ylabel("Worldwide Gross ($)")
plt.show()

# %% [markdown]
# ### **Box Plot**

# %%
# plotting boxplot plot based on grade vs rating
sns.boxplot(data=movie, x="Grade", y="Rating")
plt.title("Rating Distribution by Grade")
plt.show()

# %% [markdown]
# ### **Histograph**

# %%
# caluclating profit margin from worldwide and domestic sale
movie["Profit_Margin"] = (movie["$Worldwide"] - movie["$Domestic"]) / movie["$Domestic"]
# plotting histograph based on the recently calculated profit margin
sns.histplot(movie["Profit_Margin"], bins=30, kde=True)
plt.title("Distribution of Profit Margin")
plt.show()

# %% [markdown]
# ### **BarPlot**

# %%
# caluclating average rating based on rating
avg_rating = movie.groupby("Grade")["Rating"].mean().reset_index()
# plotting barplt based on the recently calculated paverage rating
sns.barplot(data=avg_rating, x="Grade", y="Rating")
plt.title("Average Rating by Grade")
plt.show()

# %% [markdown]
# ### **HeatMap**

# %%
# plotting a heatmap based on different parameters
corr = movie[["$Worldwide","$Domestic","$Foreign","Domestic %","Foreign %","Rating","Vote_Count"]].corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
